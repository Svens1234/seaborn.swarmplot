# %%
import seaborn as sns

# %%
sns.set_theme(style="whitegrid")

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ax = sns.swarmplot(x=tips["total_bill"])

# %%
ax = sns.swarmplot(x="day", y="total_bill", data=tips)

# %%
ax = sns.swarmplot(x="total_bill", y="day", data=tips)

# %%
ax = sns.swarmplot(x="day", y="total_bill", hue="sex", data=tips)

# %%
ax = sns.swarmplot(x="day", y="total_bill", hue="smoker",
                   data=tips, palette="Set2", dodge=True)
# Out:
# c:\python\python38\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
ax = sns.swarmplot(x="day", y="total_bill", hue="smoker",
                   data=tips, palette="Set2", dodge=False)

# %%
ax = sns.swarmplot(x="time", y="total_bill", data=tips,
                   order=["Dinner", "Lunch"])

# %%
ax = sns.swarmplot(x="time", y="total_bill", data=tips, size=6)
